# %%
# !cp '/content/drive/MyDrive/MS DL NLP Final Project/Dataset/MaxPooledFeatures.zip' /content/
# !unzip MaxPooledFeatures.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/MaxPooledFeatures/515684832.npz
#   inflating: content/MaxPooledFeatures/267325341.npz
#   inflating: content/MaxPooledFeatures/7199344342.npz
#   inflating: content/MaxPooledFeatures/6899246013.npz
#   inflating: content/MaxPooledFeatures/5687835693.npz
#   inflating: content/MaxPooledFeatures/1547327107.npz
#   inflating: content/MaxPooledFeatures/1690350208.npz
#   inflating: content/MaxPooledFeatures/2148916767.npz
#   inflating: content/MaxPooledFeatures/241345770.npz
#   inflating: content/MaxPooledFeatures/4929777339.npz
#   inflating: content/MaxPooledFeatures/3117602933.npz
#   inflating: content/MaxPooledFeatures/6960287365.npz
#   inflating: content/MaxPooledFeatures/4805425261.npz
#   inflating: content/MaxPooledFeatures/459560684.npz
#   inflating: content/MaxPooledFeatures/2163780897.npz
#   inflating: content/MaxPooledFeatures/4950996568.npz
#   inflating: content/MaxPooledFeatures/350588129.npz
#   inflating: content/MaxPooledFeatures/3399944164.npz
#   inflating: content/MaxPooledFeatures/4956164135.npz
#   inflating: content/MaxPooledFeatures/128395441.npz
#   inflating: content/MaxPooledFeatures/1349095760.npz
#   inflating: content/MaxPooledFeatures/4628572465.npz
#   inflating: content/MaxPooledFeatures/5016890643.npz
#   inflating: content/MaxPooledFeatures/5500650754.npz
#   inflating: content/MaxPooledFeatures/3401343154.npz
#   inflating: content/MaxPooledFeatures/3498482871.npz
#   inflating: content/MaxPooledFeatures/4827600483.npz
#   inflating: content/MaxPooledFeatures/6153400574.npz
#   inflating: content/MaxPooledFeatures/1468182643.npz
#   inflating: content/MaxPooledFeatures/3187105570.npz
#   inflating: content/MaxPooledFeatures/4936345449.npz
#   inflating: content/MaxPooledFeatures/23008340.npz
#   inflating: content/MaxPooledFeatures/2588763665.npz
#   inflating: content/MaxPooledFeatures/533854547.npz
#   inflating: content/MaxPooledFeatures/7052167961.npz
#   inflating: content/MaxPooledFeatures/3018255724.npz
#   inflating: content/MaxPooledFeatures/2450461962.npz
#   inflating: content/MaxPooledFeatures/3607405494.npz
#   inflating: content/MaxPooledFeatures/196437391.npz
#   inflating: content/MaxPooledFeatures/4704578554.npz
#   inflating: content/MaxPooledFeatures/3092002594.npz
#   inflating: content/MaxPooledFeatures/3676289259.npz
#   inflating: content/MaxPooledFeatures/4777133573.npz
#   inflating: content/MaxPooledFeatures/4029583519.npz
#   inflating: content/MaxPooledFeatures/476763228.npz
#   inflating: content/MaxPooledFeatures/4735982439.npz
#   inflating: content/MaxPooledFeatures/2319963351.npz
#   inflating: content/MaxPooledFeatures/4917939779.npz
#   inflating: content/MaxPooledFeatures/4706794395.npz
#   inflating: content/MaxPooledFeatures/5060860492.npz
#   inflating: content/MaxPooledFeatures/3653462288.npz
#   inflating: content/MaxPooledFeatures/2700625647.npz
#   inflating: content/MaxPooledFeatures/2922302990.npz
#   inflating: content/MaxPooledFeatures/7598946.npz
#   inflating: content/MaxPooledFeatures/2561319255.npz
#   inflating: content/MaxPooledFeatures/170100272.npz
#   inflating: content/MaxPooledFeatures/3574847368.npz
#   inflating: content/MaxPooledFeatures/4851246557.npz
#   inflating: content/MaxPooledFeatures/3944001513.npz
#   inflating: content/MaxPooledFeatures/7391785714.npz
#   inflating: content/MaxPooledFeatures/5861612441.npz
#   inflating: content/MaxPooledFeatures/2867174889.npz
#   inflating: content/MaxPooledFeatures/3244470342.npz
#   inflating: content/MaxPooledFeatures/3475257782.npz
#   inflating: content/MaxPooledFeatures/3478877323.npz
#   inflating: content/MaxPooledFeatures/2422482455.npz
#   inflating: content/MaxPooledFeatures/149934002.npz
#   inflating: content/MaxPooledFeatures/839295615.npz
#   inflating: content/MaxPooledFeatures/661755629.npz
#   inflating: content/MaxPooledFeatures/2721656220.npz
#   inflating: content/MaxPooledFeatures/4987363775.npz
#   inflating: content/MaxPooledFeatures/1301978702.npz
#   inflating: content/MaxPooledFeatures/6556869765.npz
#   inflating: content/MaxPooledFeatures/6775386680.npz
#   inflating: content/MaxPooledFeatures/1457162537.npz
#   inflating: content/MaxPooledFeatures/4052526123.npz
#   inflating: content/MaxPooledFeatures/4775776532.npz
#   inflating: content/MaxPooledFeatures/2700147489.npz
#   inflating: content/MaxPooledFeatures/2991335410.npz
#   inflating: content/MaxPooledFeatures/4888431749.npz
#   inflating: content/MaxPooledFeatures/3399751464.npz
#   inflating: content/MaxPooledFeatures/1301292439.npz
#   inflating: content/MaxPooledFeatures/6260674203.npz
#   inflating: content/MaxPooledFeatures/2725441885.npz
#   inflating: content/MaxPooledFeatures/4048837850.npz
#   inflating: content/MaxPooledFeatures/4119940755.npz
#   inflating: content/MaxPooledFeatures/3839127400.npz
#   inflating: content/MaxPooledFeatures/460973814.npz
#   inflating: content/MaxPooledFeatures/55473406.npz
#   inflating: content/MaxPooledFeatures/2528521798.npz
#   inflating: content/MaxPooledFeatures/6953548178.npz
#   inflating: content/MaxPooledFeatures/5495428438.npz
#   inflating: content/MaxPooledFeatures/4218698350.npz
#   inflating: content/MaxPooledFeatures/2913097619.npz
#   inflating: content/MaxPooledFeatures/3202255152.npz
#   inflating: content/MaxPooledFeatures/2612608861.npz
#   inflating: content/MaxPooledFeatures/1694114389.npz
#   inflating: content/MaxPooledFeatures/890734502.npz
#   inflating: content/MaxPooledFeatures/4612060755.npz
#   inflating: content/MaxPooledFeatures/4533797010.npz
#   inflating: content/MaxPooledFeatures/244774022.npz
#   inflating: content/MaxPooledFeatures/218553496.npz
#   inflating: content/MaxPooledFeatures/4088616577.npz
#   inflating: content/MaxPooledFeatures/2424250856.npz
#   inflating: content/MaxPooledFeatures/5157088977.npz
#   inflating: content/MaxPooledFeatures/2167644298.npz
#   inflating: content/MaxPooledFeatures/4889481566.npz
#   inflating: content/MaxPooledFeatures/4975221752.npz
#   inflating: content/MaxPooledFeatures/3164423279.npz
#   inflating: content/MaxPooledFeatures/145754126.npz
#   inflating: content/MaxPooledFeatures/2757779501.npz
#   inflating: content/MaxPooledFeatures/3517466790.npz
#   inflating: content/MaxPooledFeatures/4078158395.npz
#   inflating: content/MaxPooledFeatures/4901651849.npz
#   inflating: content/MaxPooledFeatures/2434440010.npz
#   inflating: content/MaxPooledFeatures/718571889.npz
#   inflating: content/MaxPooledFeatures/470887781.npz
#   inflating: content/MaxPooledFeatures/1332722096.npz
#   inflating: content/MaxPooledFeatures/2953680766.npz
#   inflating: content/MaxPooledFeatures/185960419.npz
#   inflating: content/MaxPooledFeatures/4412825867.npz
#   inflating: content/MaxPooledFeatures/3709522287.npz
#   inflating: content/MaxPooledFeatures/2537755800.npz
#   inflating: content/MaxPooledFeatures/4043319999.npz
#   inflating: content/MaxPooledFeatures/4302494145.npz
#   inflating: content/MaxPooledFeatures/1238084765.npz
#   inflating: content/MaxPooledFeatures/6447635819.npz
#   inflating: content/MaxPooledFeatures/3209564153.npz
#   inflating: content/MaxPooledFeatures/1521623639.npz
#   inflating: content/MaxPooledFeatures/12974441.npz
#   inflating: content/MaxPooledFeatures/2836703077.npz
#   inflating: content/MaxPooledFeatures/4141748393.npz
#   inflating: content/MaxPooledFeatures/732780960.npz
#   inflating: content/MaxPooledFeatures/2445654384.npz
#   inflating: content/MaxPooledFeatures/4448569088.npz
#   inflating: content/MaxPooledFeatures/2166417615.npz
#   inflating: content/MaxPooledFeatures/5926326440.npz
#   inflating: content/MaxPooledFeatures/6676181181.npz
#   inflating: content/MaxPooledFeatures/4914567687.npz
#   inflating: content/MaxPooledFeatures/2767276277.npz
#   inflating: content/MaxPooledFeatures/3241298741.npz
#   inflating: content/MaxPooledFeatures/2675397335.npz
#   inflating: content/MaxPooledFeatures/5643010407.npz
#   inflating: content/MaxPooledFeatures/2450403073.npz
#   inflating: content/MaxPooledFeatures/2215770048.npz
#   inflating: content/MaxPooledFeatures/514222303.npz
#   inflating: content/MaxPooledFeatures/3535664885.npz
#   inflating: content/MaxPooledFeatures/2597308074.npz
#   inflating: content/MaxPooledFeatures/747242766.npz
#   inflating: content/MaxPooledFeatures/1317292658.npz
#   inflating: content/MaxPooledFeatures/524698457.npz
#   inflating: content/MaxPooledFeatures/2929137203.npz
#   inflating: content/MaxPooledFeatures/1433262517.npz
#   inflating: content/MaxPooledFeatures/3487015378.npz
#   inflating: content/MaxPooledFeatures/4329198220.npz
#   inflating: content/MaxPooledFeatures/4813609218.npz
#   inflating: content/MaxPooledFeatures/5942795175.npz
#   inflating: content/MaxPooledFeatures/559852881.npz
#   inflating: content/MaxPooledFeatures/3974156067.npz
#   inflating: content/MaxPooledFeatures/96420612.npz
#   inflating: content/MaxPooledFeatures/5897560750.npz
#   inflating: content/MaxPooledFeatures/2884420269.npz
#   inflating: content/MaxPooledFeatures/447357501.npz
#   inflating: content/MaxPooledFeatures/2844846111.npz
#   inflating: content/MaxPooledFeatures/2904999450.npz
#   inflating: content/MaxPooledFeatures/2980445969.npz
#   inflating: content/MaxPooledFeatures/6167795092.npz
#   inflating: content/MaxPooledFeatures/526619673.npz
#   inflating: content/MaxPooledFeatures/407453309.npz
#   inflating: content/MaxPooledFeatures/6944520638.npz
#   inflating: content/MaxPooledFeatures/409220780.npz
#   inflating: content/MaxPooledFeatures/3564335184.npz
#   inflating: content/MaxPooledFeatures/4609086520.npz
#   inflating: content/MaxPooledFeatures/4054618575.npz
#   inflating: content/MaxPooledFeatures/758921886.npz
#   inflating: content/MaxPooledFeatures/3183354360.npz
#   inflating: content/MaxPooledFeatures/539493431.npz
#   inflating: content/MaxPooledFeatures/2947452329.npz
#   inflating: content/MaxPooledFeatures/2845845721.npz
#   inflating: content/MaxPooledFeatures/1158897994.npz
#   inflating: content/MaxPooledFeatures/3472372634.npz
#   inflating: content/MaxPooledFeatures/4817804359.npz
#   inflating: content/MaxPooledFeatures/122202217.npz
#   inflating: content/MaxPooledFeatures/1006452823.npz
#   inflating: content/MaxPooledFeatures/4590247366.npz
#   inflating: content/MaxPooledFeatures/21833287.npz
#   inflating: content/MaxPooledFeatures/4975172155.npz
#   inflating: content/MaxPooledFeatures/760702109.npz
#   inflating: content/MaxPooledFeatures/3809063851.npz
#   inflating: content/MaxPooledFeatures/4591391059.npz
#   inflating: content/MaxPooledFeatures/3068407619.npz
#   inflating: content/MaxPooledFeatures/3640020134.npz
#   inflating: content/MaxPooledFeatures/2691271455.npz
#   inflating: content/MaxPooledFeatures/1925434818.npz
#   inflating: content/MaxPooledFeatures/5534272962.npz
#   inflating: content/MaxPooledFeatures/2429369147.npz
#   inflating: content/MaxPooledFeatures/528498076.npz
#   inflating: content/MaxPooledFeatures/4930690081.npz
#   inflating: content/MaxPooledFeatures/6744212617.npz
#   inflating: content/MaxPooledFeatures/3815669424.npz
#   inflating: content/MaxPooledFeatures/3520869880.npz
#   inflating: content/MaxPooledFeatures/841397013.npz
#   inflating: content/MaxPooledFeatures/199413572.npz
#   inflating: content/MaxPooledFeatures/2955985301.npz
#   inflating: content/MaxPooledFeatures/6857646118.npz
#   inflating: content/MaxPooledFeatures/335009007.npz
#   inflating: content/MaxPooledFeatures/4928550914.npz
#   inflating: content/MaxPooledFeatures/4108479912.npz
#   inflating: content/MaxPooledFeatures/6179361394.npz
#   inflating: content/MaxPooledFeatures/1477503966.npz
#   inflating: content/MaxPooledFeatures/289638863.npz
#   inflating: content/MaxPooledFeatures/300022551.npz
#   inflating: content/MaxPooledFeatures/4818774874.npz
#   inflating: content/MaxPooledFeatures/4002498838.npz
#   inflating: content/MaxPooledFeatures/4523882717.npz
#   inflating: content/MaxPooledFeatures/409198440.npz
#   inflating: content/MaxPooledFeatures/7524171640.npz
#   inflating: content/MaxPooledFeatures/6943740971.npz
#   inflating: content/MaxPooledFeatures/4589027891.npz
#   inflating: content/MaxPooledFeatures/2445069108.npz
#   inflating: content/MaxPooledFeatures/2474615549.npz
#   inflating: content/MaxPooledFeatures/1550772959.npz
#   inflating: content/MaxPooledFeatures/451875908.npz
#   inflating: content/MaxPooledFeatures/3471747180.npz
#   inflating: content/MaxPooledFeatures/149588792.npz
#   inflating: content/MaxPooledFeatures/7796225106.npz
#   inflating: content/MaxPooledFeatures/3027282153.npz
#   inflating: content/MaxPooledFeatures/2784073733.npz
#   inflating: content/MaxPooledFeatures/1269022629.npz
#   inflating: content/MaxPooledFeatures/708204852.npz
#   inflating: content/MaxPooledFeatures/4730789283.npz
#   inflating: content/MaxPooledFeatures/4621123071.npz
#   inflating: content/MaxPooledFeatures/4467431522.npz
#   inflating: content/MaxPooledFeatures/44341044.npz
#   inflating: content/MaxPooledFeatures/3415578043.npz
#   inflating: content/MaxPooledFeatures/4272403632.npz
#   inflating: content/MaxPooledFeatures/2308029439.npz

# %% [markdown]
# #### Imports

# %%
# Imports
import numpy as np
import tensorflow as tf

# %% [markdown]
# #### Util Functions

# %%
# Util function for Positional Encoding
def positional_encoding(length, depth):
    depth = depth / 2
    positions = np.arange(length)[:, np.newaxis]     # (seq, 1)
    depths = np.arange(depth)[np.newaxis, :] / depth   # (1, depth)
    angle_rates = 1 / (10000 ** depths)         # (1, depth)
    angle_rads = positions * angle_rates      # (pos, depth)
    pos_encoding = np.concatenate([np.sin(angle_rads), np.cos(angle_rads)], axis = -1)
    return tf.cast(pos_encoding, dtype = tf.float32)

# %%
# Positional Embedding
class PositionalEmbedding(tf.keras.layers.Layer):
  def __init__(self, vocab_size, d_model):
    super().__init__()
    self.d_model = d_model
    self.embedding = tf.keras.layers.Embedding(vocab_size, d_model, mask_zero = True)
    self.pos_encoding = positional_encoding(length = 2048, depth = d_model)

  def compute_mask(self, *args, **kwargs):
    return self.embedding.compute_mask(*args, **kwargs)

  def call(self, x):
    length = tf.shape(x)[1]
    x = self.embedding(x)
    # This factor sets the relative scale of the embedding and positonal_encoding.
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x = x + self.pos_encoding[tf.newaxis, :length, :]
    return x

# %%
# Base Attention - Used to define child (cross / global / masked) attention layers
class BaseAttention(tf.keras.layers.Layer):
  def __init__(self, **kwargs):
    super().__init__()
    self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
    self.layernorm = tf.keras.layers.LayerNormalization()
    self.add = tf.keras.layers.Add()

# Global Self Attention - Used in Encoder
class GlobalSelfAttention(BaseAttention):
  def call(self, x):
    attn_output = self.mha(query = x, value = x, key = x)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

# Causal (Masked) Self Attention - Used in Decoder
class CausalSelfAttention(BaseAttention):
  def call(self, x):
    attn_output = self.mha(query = x, value = x, key = x, use_causal_mask = True)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

# Cross Attention - Used in Decoder
class CrossAttention(BaseAttention):
  def call(self, x, context):
    attn_output, attn_scores = self.mha(query = x, key = context, value = context, return_attention_scores = True)
    self.last_attn_scores = attn_scores
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

# %%
# Feed Forward Layers - Used in both Encoder and Decoder
class FeedForward(tf.keras.layers.Layer):
  def __init__(self, d_model, dff, dropout_rate = 0.1):
    super().__init__()
    self.seq = tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation = 'relu'),
      tf.keras.layers.Dense(d_model),
      tf.keras.layers.Dropout(dropout_rate)
    ])
    self.add = tf.keras.layers.Add()
    self.layer_norm = tf.keras.layers.LayerNormalization()

  def call(self, x):
    x = self.add([x, self.seq(x)])
    x = self.layer_norm(x)
    return x

# %%
# Encoder Layer
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self,*, d_model, num_heads, dff, dropout_rate = 0.1):
    super().__init__()
    self.self_attention = GlobalSelfAttention(num_heads = num_heads, key_dim = d_model, dropout = dropout_rate)
    self.ffn = FeedForward(d_model, dff)

  def call(self, x):
    x = self.self_attention(x)
    x = self.ffn(x)
    return x

# %%
# Encoder
class Encoder(tf.keras.layers.Layer):
  def __init__(self, *, num_layers, d_model, num_heads, dff, vocab_size, dropout_rate = 0.1):
    super().__init__()
    self.d_model = d_model
    self.num_layers = num_layers
    self.pos_embedding = PositionalEmbedding(vocab_size = vocab_size, d_model = d_model)
    self.enc_layers = [EncoderLayer(d_model = d_model, num_heads = num_heads, dff = dff, dropout_rate = dropout_rate) for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(dropout_rate)

  def call(self, x):
    # `x` is token-IDs shape: (batch, seq_len)
    x = self.pos_embedding(x)  # Shape `(batch_size, seq_len, d_model)`.

    # Add dropout.
    x = self.dropout(x)

    for i in range(self.num_layers):
      x = self.enc_layers[i](x)

    return x  # Shape `(batch_size, seq_len, d_model)`.

# %%
# Decoder Layer
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, *, d_model, num_heads, dff, dropout_rate = 0.1):
    super(DecoderLayer, self).__init__()
    self.causal_self_attention = CausalSelfAttention(num_heads = num_heads, key_dim = d_model, dropout = dropout_rate)
    self.cross_attention = CrossAttention(num_heads = num_heads, key_dim = d_model, dropout = dropout_rate)
    self.ffn = FeedForward(d_model, dff)

  def call(self, x, context):
    x = self.causal_self_attention(x = x)
    x = self.cross_attention(x = x, context = context)

    # Cache the last attention scores for plotting later
    self.last_attn_scores = self.cross_attention.last_attn_scores

    x = self.ffn(x)  # Shape `(batch_size, seq_len, d_model)`.
    return x

# %%
# Decoder
class Decoder(tf.keras.layers.Layer):
  def __init__(self, *, num_layers, d_model, num_heads, dff, vocab_size, dropout_rate = 0.1):
    super(Decoder, self).__init__()
    self.d_model = d_model
    self.num_layers = num_layers
    self.pos_embedding = PositionalEmbedding(vocab_size = vocab_size, d_model = d_model)
    self.dropout = tf.keras.layers.Dropout(dropout_rate)
    self.dec_layers = [DecoderLayer(d_model = d_model, num_heads = num_heads,dff = dff, dropout_rate = dropout_rate) for _ in range(num_layers)]
    self.last_attn_scores = None

  def call(self, x, context):
    # `x` is token-IDs shape (batch, target_seq_len)
    x = self.pos_embedding(x)  # (batch_size, target_seq_len, d_model)

    x = self.dropout(x)

    for i in range(self.num_layers):
      x  = self.dec_layers[i](x, context)

    self.last_attn_scores = self.dec_layers[-1].last_attn_scores

    # The shape of x is (batch_size, target_seq_len, d_model).
    return x

# %% [markdown]
# #### Model

# %%
# Name of the Model - EfficientDecoder
class EfficientDecoder(tf.keras.Model):
  def __init__(self, *, num_layers, d_model, num_heads, dff, target_vocab_size, dropout_rate = 0.1):
    super().__init__()

    # Dense layer for mapping image encodings to d_model
    self.dense = tf.keras.layers.Dense(d_model, activation = 'relu')

    # Only utilize Decoder part of the Transformer Model, will be using EfficientNetB4 as Image Encoder explicitly
    # For training, we have already extracted image encodings and store as np arrays to save computations.
    # During inference, we will build pipeline: Inputs -> EfficientNetB4 -> EfficientDecoder -> Output
    self.decoder = Decoder(num_layers = num_layers, d_model = d_model,
                           num_heads = num_heads, dff = dff,
                           vocab_size = target_vocab_size,
                           dropout_rate = dropout_rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)

  def call(self, inputs):
    # To use a Keras model with `.fit` you must pass all your inputs in the
    # first argument.
    # context is image encodings (bs, seeq_len, img_enc), x is decoder input sequence (bs, seq_len)
    context, x  = inputs
    context = self.dense(context) # (bs, seq_len, d_model)
    x = self.decoder(x, context)  # (bs, seq_len, d_model)
    logits = self.final_layer(x)  # (bs, seq_len, target_vocab_size)

    try:
      # Drop the keras mask, so it doesn't scale the losses/metrics.
      # b/250038731
      del logits._keras_mask
    except AttributeError:
      pass

    # Return the final output and the attention weights.
    return logits

# %% [markdown]
# #### Unit Test

# %%
# Dummy Caption - This should be NE (Numerical Encoded) Vectors of Words from Target Vocab
x = np.random.randn(1, 50) # (bs, seq_len)

# Load Image (Context)
file_path = '/content/MaxPooledFeatures/36979.npz'
image_encodings = np.load(file_path)
key = 'arr_0'

# Assert Shape
context = image_encodings[key]
assert context.shape == (1792, )

# Reshape for Model
context = np.tile(np.expand_dims(context, axis = 0), (1, 50, 1)) # (bs, seq_len, img_enc)

# Model Parameters
num_layers = 3
d_model = 512
num_heads = 4
dff = 2048
target_vocab_size = 1000

# Define Model
model = EfficientDecoder(num_layers = num_layers, d_model = d_model, num_heads = num_heads, target_vocab_size = target_vocab_size, dff = dff)
op = model((context, x))
print(op.shape)
# Out:
# (1, 50, 1000)

# %% [markdown]
# #### Check GIT

# %%
# !git clone https://github.com/jainamshah17/dlnlpfinalproject.git
# Out:
# Cloning into 'dlnlpfinalproject'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0
# Receiving objects: 100% (5/5), done.

# %%
# Import
import sys
sys.path.append('/content/dlnlpfinalproject/')

from model import EfficientDecoder as EDGit

# %%
# !python /content/dlnlpfinalproject/unit_test.py
# Out:
# 2023-11-23 21:37:10.687597: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-23 21:37:10.687658: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-23 21:37:10.687702: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-23 21:37:12.258576: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-11-23 21:37:15.274895: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# (1, 50, 1000)

# %%
# Define Model from Git
model = EDGit(num_layers = num_layers, d_model = d_model, num_heads = num_heads, target_vocab_size = target_vocab_size, dff = dff)
op = model((context, x))
print(op.shape)
# Out:
# (1, 50, 1000)
